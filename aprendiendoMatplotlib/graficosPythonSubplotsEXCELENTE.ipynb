# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0, 10, 0.1)
y1 = x ** 2
y2 = x ** 0.5

# %%
fig, ax = plt.subplots()
ax.plot(x, y1)
ax.plot(x, y2)
# plt.show()

# %%
fig, ax = plt.subplots(3, 2)
ax[0, 0].plot(x, y)
ax[2, 1].plot(x, y1)
plt.tight_layout()

# %%
fig, ax = plt.subplots(1, 2, sharey=True)
ax[0].plot(x, y1, color="r", linestyle="--")
ax[1].plot(x, y2, marker="v")

ax[0].set_xlabel("Valores de X 1")
ax[1].set_xlabel("Valores de X 2")
ax[0].set_ylabel("Valores para Y")

ax[0].set_title("Gráfico pedorro 1")
ax[1].set_title("Gráfico pedorro 2")
# Out:
# Text(0.5, 1.0, 'Gráfico pedorro 2')

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)                   # Esta es otra manera de poner los subplots!
# ax[0].plot(x, y1, color="r", linestyle="--")
# ax[1].plot(x, y2, marker="v")

# ax[1].set_xlabel("Valores de X")
# ax[0].set_ylabel("Valores para Y 1")
# ax[1].set_ylabel("Valores para Y 2")

# ax[0].set_title("Gráfico pedorro 1")

ax1.plot(x, y1, color="r", linestyle="--")
ax2.plot(x, y2, marker="v")

ax2.set_xlabel("Valores de X")
ax1.set_ylabel("Valores para Y 1")
ax2.set_ylabel("Valores para Y 2")

ax1.set_title("Gráfico pedorro 1")
# Out:
# Text(0.5, 1.0, 'Gráfico pedorro 1')
